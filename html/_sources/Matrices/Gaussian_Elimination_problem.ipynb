# %% [markdown]
# # Guassian Elimination
# ## write your name here

# %%
import numpy as np

# %%
def forward_sub(L,b):
    
    n=b.size
    x=np.zeros(n)
    
    for i in range(n):
        x[i] = (b[i] - np.dot(L[i,:i],x[i+1:]))/L[i,i]
                
    return x

def backward_sub(U,b):
    
    n=b.size
    x=np.zeros(n) 
    
    x[n-1]=b[n-1]/U[n-1, n-1]
    
    for i in reversed(range(n-1)):
        
        x[i] = (b[i] - np.dot(U[i, i+1:],x[i+1:]))/U[i,i]
                
    return x

def gauss_elim(A_in, b_in):
    
    A=np.copy(A_in)
    b=np.copy(b_in) 
    
    # finish the code

# %% [markdown]
# ## Problem
# Use your Gaussian elimination code to solve the following.
#
# \begin{align}
# & x + 2y - z = 3 \\
# & 2x + y - 2z = 3 \\
# & -3x + y + z = -6
# \end{align}
#
# Upload a pdf or html copy of your notebook.
