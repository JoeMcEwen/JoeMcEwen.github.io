# %% [markdown]
# # Eigenvalues and Eigenvectors

# %% [markdown]
# Let us consider the following equation
# \begin{equation}
# \begin{bmatrix}
# 4 & -2 & 1 \\
# -2 & 1 & -2 \\
# 1 & -2 & 4
# \end{bmatrix}
# \begin{bmatrix} 1 \\ -1 \\ 1
# \end{bmatrix} = \begin{bmatrix} 7 \\ -7 \\ 7
# \end{bmatrix} = 7 \begin{bmatrix} 1 \\ -1 \\ 1
# \end{bmatrix}
# \end{equation}
#
#
# Example looks wrong....
#
# '''
# sections:
# Define eigenvalue and eigenvector through the equaiton.
# Explain degenerate.
# All the above with Python code.
# What is the intuition for the eigenvalue problem.
# Give example uses.
# '''

# %%
import numpy as np

# %%
A  = np.array([[4, -2, 1], [-2, 1, -2], [1, -2, 4]]) 
v = np.array([1, -1, 1]) 
np.dot(A, v)
# Out:
# array([ 7, -5,  7])
